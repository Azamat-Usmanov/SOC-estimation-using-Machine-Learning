# %% [markdown]
# ## Merge of LG and Panasonic data

# %%
import os
import pandas as pd

# %%
base_dir = '../../datasets'
lg_dir = os.path.join(base_dir, 'LG_dataset', 'LG_HG2_processed')
panasonic_dir = os.path.join(base_dir, 'Panasonic_dataset', 'Panasonic_processed')
combined_dir = os.path.join(base_dir, 'combined_dataset')
os.makedirs(combined_dir, exist_ok=True)

# %%
drive_cycles = ['UDDS', 'LA92', 'US06', 'HWFET', 'HWFT', 'HPPC', 'NN']

temp_folders = ['0degC', '10degC', '25degC', '40degC', 'n10degC', 'n20degC']

additional_cycles = ['Mixed', 'Cycle']

# %%
def is_drive_cycle_file(filename):
    return any(cycle in filename for cycle in drive_cycles)

# %%
def is_additional_cycle_file(filename):
    return any(cycle in filename for cycle in additional_cycles)

# %%
for temp_folder in temp_folders:
    lg_temp_path = os.path.join(lg_dir, temp_folder)
    if os.path.exists(lg_temp_path):
        combined_temp_path = os.path.join(combined_dir, temp_folder)
        os.makedirs(combined_temp_path, exist_ok=True)
        
        for file in os.listdir(lg_temp_path):
            if file.endswith('.csv'):
                src_path = os.path.join(lg_temp_path, file)
                dst_path = os.path.join(combined_temp_path, file.replace('LG_', ''))
                
                if is_additional_cycle_file(file) or is_drive_cycle_file(file):
                    df = pd.read_csv(src_path)
                    df.to_csv(dst_path, index=False)
                    print(f"Скопирован LG файл: {dst_path}")

    if temp_folder != '40degC':
        panasonic_temp_path = os.path.join(panasonic_dir, temp_folder)
        if os.path.exists(panasonic_temp_path):
            combined_temp_path = os.path.join(combined_dir, temp_folder)
            os.makedirs(combined_temp_path, exist_ok=True)
            
            for file in os.listdir(panasonic_temp_path):
                if file.endswith('.csv'):
                    src_path = os.path.join(panasonic_temp_path, file)
                    dst_path = os.path.join(combined_temp_path, file.replace('Panasonic_', ''))
                    
                    if is_additional_cycle_file(file) or is_drive_cycle_file(file):
                        df = pd.read_csv(src_path)
                        
                        columns_to_drop = ['Voltage Average', 'Current Average']
                        for col in columns_to_drop:
                            if col in df.columns:
                                df.drop(col, axis=1, inplace=True)
                        
                        df.to_csv(dst_path, index=False)
                        print(f"Скопирован и обработан Panasonic файл: {dst_path}")
# Out:
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/590_Mixed8_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/590_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/590_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/590_Mixed4_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/590_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_HWFET_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/585_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_UDDS_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/0degC/589_LA92_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/05-30-17_20.16 0degC_Cycle_2_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-01-17_15.36 0degC_Cycle_3_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-02-17_04.58 0degC_US06_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/05-30-17_12.56 0degC_Cycle_1_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-02-17_17.14 0degC_UDDS_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-01-17_10.36 0degC_LA92_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-01-17_10.36 0degC_NN_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-02-17_10.43 0degC_HWFET_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/0degC/06-01-17_22.03 0degC_Cycle_4_Pan18650PF_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/567_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/571_Mixed8_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/567_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/567_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/571_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/576_UDDS_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/571_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/571_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/575_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/571_Mixed4_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/10degC/576_HWFET_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/04-05-17_17.04 10degC_Cycle_3_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-27-17_09.06 10degC_LA92_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-27-17_09.06 10degC_UDDS_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-28-17_18.18 10degC_Cycle_2_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-27-17_09.06 10degC_NN_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-27-17_09.06 10degC_US06_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/04-05-17_22.50 10degC_Cycle_4_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-28-17_12.51 10degC_Cycle_1_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/10degC/03-27-17_09.06 10degC_HWFET_Pan18650PF_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed3_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/549_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/551_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/551_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/551_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed4_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/551_LA92_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/552_Mixed8_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/25degC/551_UDDS_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-21-17_09.38 25degC_LA92_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-20-17_19.27 25degC_HWFTb_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-19-17_09.07 25degC_Cycle_3_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-20-17_05.56 25degC_HWFTa_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-21-17_00.29 25degC_UDDS_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-20-17_01.43 25degC_US06_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-18-17_02.17 25degC_Cycle_1_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-19-17_03.25 25degC_Cycle_2_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-19-17_14.31 25degC_Cycle_4_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/25degC/03-21-17_16.27 25degC_NN_Pan18650PF_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/562_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/562_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/557_Mixed3_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_LA92_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/562_Mixed8_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_HWFET_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_UDDS_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/555_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/562_Mixed4_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/556_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/40degC/562_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/596_UDDS_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/596_LA92_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/604_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/604_Mixed3_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/602_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/602_Mixed4_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/596_HWFET_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/601_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/604_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/601_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/593_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/601_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n10degC/604_Mixed8_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-07-17_08.39 n10degC_UDDS_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-11-17_08.42 n10degC_Cycle_4_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-07-17_08.39 n10degC_LA92_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-07-17_08.39 n10degC_US06_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-10-17_18.35 n10degC_Cycle_2_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-11-17_01.39 n10degC_Cycle_3_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-10-17_11.25 n10degC_Cycle_1_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-14-17_13.12 n10degC_NN_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n10degC/06-07-17_08.39 n10degC_HWFET_Pan18650PF_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed5_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed6_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed8_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_US06_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_Mixed1_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_Mixed2_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/607_HPPC_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_HWFET_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_UDDS_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed3_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed7_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/610_LA92_processed.csv
# Скопирован LG файл: ../../datasets/combined_dataset/n20degC/611_Mixed4_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-23-17_23.35 n20degC_UDDS_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-25-17_10.31 n20degC_US06_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-23-17_23.35 n20degC_LA92_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-24-17_11.58 n20degC_Cycle_2_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-24-17_19.29 n20degC_Cycle_3_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-23-17_23.35 n20degC_HWFET_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-24-17_04.29 n20degC_Cycle_1_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-25-17_03.01 n20degC_Cycle_4_Pan18650PF_processed.csv
# Скопирован и обработан Panasonic файл: ../../datasets/combined_dataset/n20degC/06-23-17_23.35 n20degC_NN_Pan18650PF_processed.csv

# %%
# for temp_folder in temp_folders:
#     panasonic_temp_path = os.path.join(panasonic_dir, temp_folder) if temp_folder != '40degC' else None
#     lg_temp_path = os.path.join(lg_dir, temp_folder)

#     if not os.path.exists(lg_temp_path):
#         continue

#     combined_temp_path = os.path.join(combined_dir, temp_folder)
#     os.makedirs(combined_temp_path, exist_ok=True)
    
#     lg_files = os.listdir(lg_temp_path)
#     panasonic_files = os.listdir(panasonic_temp_path) if panasonic_temp_path and os.path.exists(panasonic_temp_path) else []
    
#     for cycle in drive_cycles:
#         lg_cycle_files = [f for f in lg_files if cycle in f]
        
#         panasonic_cycle_files = [f for f in panasonic_files if cycle in f]
        
#         for lg_file in lg_cycle_files:
#             lg_file_path = os.path.join(lg_temp_path, lg_file)
#             lg_df = pd.read_csv(lg_file_path)

#             matching_panasonic_files = [f for f in panasonic_cycle_files if cycle in f]
            
#             if matching_panasonic_files:
#                 for panasonic_file in matching_panasonic_files:
#                     panasonic_file_path = os.path.join(panasonic_temp_path, panasonic_file)
#                     panasonic_df = pd.read_csv(panasonic_file_path)
                    
#                     columns_to_drop = ['Voltage Average', 'Current Average']
#                     for col in columns_to_drop:
#                         if col in panasonic_df.columns:
#                             panasonic_df.drop(col, axis=1, inplace=True)
                    
#                     combined_df = pd.concat([lg_df, panasonic_df], ignore_index=True)
                    
#                     base_name = os.path.splitext(lg_file)[0].replace('LG_', '').replace('_' + cycle, '')
#                     combined_filename = f"{base_name}_{cycle}_combined.csv"
#                     combined_file_path = os.path.join(combined_temp_path, combined_filename)
                    
#                     combined_df.to_csv(combined_file_path, index=False)
#                     print(f"Combined file has been created: {combined_file_path}")
#             else:
#                 base_name = os.path.splitext(lg_file)[0].replace('LG_', '').replace('_' + cycle, '')
#                 combined_filename = f"{base_name}_{cycle}_LG_only.csv"
#                 combined_file_path = os.path.join(combined_temp_path, combined_filename)
                
#                 lg_df.to_csv(combined_file_path, index=False)
